# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://www.ncei.noaa.gov/data/local-climatological-data/access/2021/"
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content, 'html.parser').find_all('a')
for link in soup:
    if link.get("href") == "01011099999.csv":
        download_uri = f"{url}{link.get('href')}"
        csv_content = requests.get(download_uri)
        open("01011099999.csv", "wb").write(csv_content.content)

# %%
df = pd.read_csv("01011099999.csv", sep=",")

# %%
df.describe()
# Out:
#             STATION      LATITUDE  LONGITUDE  ELEVATION  SOURCE  \
# count  3.330000e+02  3.330000e+02      333.0      333.0   333.0
# mean   1.011100e+09  8.006667e+01       31.5       10.0     4.0
# std    0.000000e+00  1.423224e-14        0.0        0.0     0.0
# min    1.011100e+09  8.006667e+01       31.5       10.0     4.0
# 25%    1.011100e+09  8.006667e+01       31.5       10.0     4.0
# 50%    1.011100e+09  8.006667e+01       31.5       10.0     4.0
# 75%    1.011100e+09  8.006667e+01       31.5       10.0     4.0
# max    1.011100e+09  8.006667e+01       31.5       10.0     4.0
#
#        HourlyAltimeterSetting  HourlyDewPointTemperature  \
# count                     0.0                 331.000000
# mean                      NaN                  18.567976
# std                       NaN                  13.592246
# min                       NaN                 -26.000000
# 25%                       NaN                   8.000000
# ...

# %%
df.sort_values("HourlyDryBulbTemperature", axis=0, ascending=True )
# Out:
#         STATION                 DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 78   1011099999  2021-03-13T21:00:00  80.066667       31.5       10.0
# 73   1011099999  2021-03-12T07:00:00  80.066667       31.5       10.0
# 74   1011099999  2021-03-12T08:00:00  80.066667       31.5       10.0
# 71   1011099999  2021-03-05T12:00:00  80.066667       31.5       10.0
# 47   1011099999  2021-01-31T07:00:00  80.066667       31.5       10.0
# ..          ...                  ...        ...        ...        ...
# 175  1011099999  2021-08-03T10:00:00  80.066667       31.5       10.0
# 161  1011099999  2021-07-15T20:00:00  80.066667       31.5       10.0
# 179  1011099999  2021-08-10T14:00:00  80.066667       31.5       10.0
# 165  1011099999  2021-07-16T03:00:00  80.066667       31.5       10.0
# 180  1011099999  2021-08-11T22:00:00  80.066667       31.5       10.0
#
#             NAME REPORT_TYPE  SOURCE  HourlyAltimeterSetting  \
# 78   KVITOYA, SV       FM-12       4                     NaN
# ...

# %%
new_soup = BeautifulSoup(r.content, "html.parser").find('table')
